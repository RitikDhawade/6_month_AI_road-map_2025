# %%
import numpy as np

# %%
import PIL

# %%
from PIL import Image

# %%
hourse_img = Image.open(r"C:\Users\vrush\Downloads\hourse image.jpeg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(hourse_img)

# %%
elephant_img = Image.open(r"C:\Users\vrush\Downloads\Elephant image.jpg")

# %%
plt.imshow(elephant_img)

# %%
# convert tp array
elephant_arr = np.asarray(elephant_img)

# %%
elephant_arr
# Out:
# array([[[ 98, 147, 223],
#         [ 98, 147, 223],
#         [ 98, 147, 223],
#         ...,
#         [ 86, 143, 220],
#         [ 86, 145, 221],
#         [ 86, 145, 221]],
#
#        [[ 98, 147, 223],
#         [ 98, 147, 223],
#         [ 98, 147, 223],
#         ...,
#         [ 86, 143, 220],
#         [ 86, 145, 221],
#         [ 86, 145, 221]],
#
#        [[ 97, 146, 222],
#         [ 97, 146, 222],
#         [ 97, 146, 222],
#         ...,
#         [ 87, 144, 221],
#         [ 87, 144, 221],
#         [ 87, 144, 221]],
#
#        ...,
#
#        [[159, 121,  58],
#         [161, 123,  60],
#         [163, 125,  62],
#         ...,
#         [127, 104,  34],
#         [127, 104,  34],
#         [125, 102,  32]],
#
#        [[160, 122,  59],
#         [161, 123,  60],
#         [163, 125,  62],
#         ...,
#         [126, 103,  35],
#         [125, 102,  34],
#         [123, 100,  32]],
#
#        [[160, 122,  59],
#         [161, 123,  60],
#         [162, 124,  61],
# ...

# %%
elephant_red = elephant_arr.copy()

# %%
elephant_red
# Out:
# array([[[ 98, 147, 223],
#         [ 98, 147, 223],
#         [ 98, 147, 223],
#         ...,
#         [ 86, 143, 220],
#         [ 86, 145, 221],
#         [ 86, 145, 221]],
#
#        [[ 98, 147, 223],
#         [ 98, 147, 223],
#         [ 98, 147, 223],
#         ...,
#         [ 86, 143, 220],
#         [ 86, 145, 221],
#         [ 86, 145, 221]],
#
#        [[ 97, 146, 222],
#         [ 97, 146, 222],
#         [ 97, 146, 222],
#         ...,
#         [ 87, 144, 221],
#         [ 87, 144, 221],
#         [ 87, 144, 221]],
#
#        ...,
#
#        [[159, 121,  58],
#         [161, 123,  60],
#         [163, 125,  62],
#         ...,
#         [127, 104,  34],
#         [127, 104,  34],
#         [125, 102,  32]],
#
#        [[160, 122,  59],
#         [161, 123,  60],
#         [163, 125,  62],
#         ...,
#         [126, 103,  35],
#         [125, 102,  34],
#         [123, 100,  32]],
#
#        [[160, 122,  59],
#         [161, 123,  60],
#         [162, 124,  61],
# ...

# %%
plt.imshow(elephant_arr)

# %%
plt.imshow(elephant_red[:,:,0])

# %%
plt.imshow(elephant_red[:,:,1])

# %%
plt.imshow(elephant_red[:,:,2])

# %%
# Apply the different colour

# %%
plt.imshow(elephant_red[:,:,0],cmap='Greys')

# %%
plt.imshow(elephant_red[:,:,1],cmap='Greys')

# %%
plt.imshow(elephant_red[:,:,1],cmap='Oranges')

# %%
plt.imshow(elephant_red[:,:,0],cmap='Oranges')

# %%
plt.imshow(elephant_red[:,:,1],cmap='Reds')

# %%
plt.imshow(elephant_red[:,:,0],cmap='Reds')

# %%
elephant_arr= 0

# %%
plt.imshow(elephant_red[:,:,0],cmap='Oranges')

# %%
plt.imshow(elephant_red[:,:,1],cmap='Blues')
